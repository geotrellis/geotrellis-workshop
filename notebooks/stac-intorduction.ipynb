# %% [markdown]
# ## Overview of supported OGC standards

# %% [markdown]
# ![logo](https://miro.medium.com/max/4800/1*DyTaIZaVaz-k6FXUVbqk0g.png)

# %% [markdown]
# The Open Geospatial Consortium (OGC) is an international voluntary consensus standards organization, originated in 1994.

# %% [markdown]
# The OGC standards baseline comprises more than 30 standards, including:
# - [WCS](https://www.ogc.org/standards/wcs) – Web Coverage Service: defines Web-based retrieval of coverages – that is, digital geospatial information representing space/time-varying phenomena
# - [WFS](https://www.ogc.org/standards/wfs) – Web Feature Service: an API for retrieving or altering feature descriptions
# - [WMS](https://www.ogc.org/standards/wms) – Web Map Service: is a standard protocol developed by the Open Geospatial Consortium in 1999 for serving georeferenced map images over the Internet.
# - [WMTS](https://www.ogc.org/standards/wmts) – Web Map Tile Service: is a standard protocol for serving pre-rendered or run-time computed georeferenced map tiles over the Internet
# - lots of other standards

# %% [markdown]
# ## STAC intro

# %% [markdown]
# - **[SpatioTemporal Asset Catalogs and the Open Geospatial Consortium](https://medium.com/radiant-earth-insights/spatiotemporal-asset-catalogs-and-the-open-geospatial-consortium-659538dce5c7) article by Chris Holmes**

# %% [markdown]
# - [OGC API - Features](https://github.com/opengeospatial/ogcapi-features)
#   - It is a multi-part standard for querying geospatial information on the web.
#   - It defines modular API building blocks to spatially enable Web APIs in a consistent way. OpenAPI is used to define the reusable API building blocks with responses in JSON and HTML.
#   - [OGC API - Features - Part 1: Core](http://docs.opengeospatial.org/is/17-069r3/17-069r3.html)

# %% [markdown]
# <table id="tldr" class="tableblock frame-all grid-all stretch">
# <caption class="title">OGC API - Features. Overview of resources, applicable HTTP methods and links to the document sections<a id="table_1"></a><a id="tldnr"></a></caption>
# <colgroup>
# <col style="width: 32%;">
# <col style="width: 25%;">
# <col style="width: 10%;">
# <col style="width: 33%;">
# </colgroup>
# <thead>
# <tr>
# <th class="tableblock halign-left valign-top" style="background-color: #FFFFFF;">Resource</th>
# <th class="tableblock halign-left valign-top" style="background-color: #FFFFFF;">Path</th>
# <th class="tableblock halign-left valign-top" style="background-color: #FFFFFF;">HTTP method</th>
# <th class="tableblock halign-left valign-top" style="background-color: #FFFFFF;">Document reference</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="tableblock halign-left valign-top" style="background-color: #FFFFFF;"><p class="tableblock">Landing page</p></td>
# <td class="tableblock halign-left valign-top" style="background-color: #FFFFFF;"><p class="tableblock"><code>/</code></p></td>
# <td class="tableblock halign-left valign-top" style="background-color: #FFFFFF;"><p class="tableblock">GET</p></td>
# <td class="tableblock halign-left valign-top" style="background-color: #FFFFFF;"><p class="tableblock"><a href="http://docs.opengeospatial.org/is/17-069r3/17-069r3.html#_api_landing_page">7.2 API landing page</a></p></td>
# </tr>
# <tr>
# <td class="tableblock halign-left valign-top" style="background-color: #FFFFFF;"><p class="tableblock">Conformance declaration</p></td>
# <td class="tableblock halign-left valign-top" style="background-color: #FFFFFF;"><p class="tableblock"><code>/conformance</code></p></td>
# <td class="tableblock halign-left valign-top" style="background-color: #FFFFFF;"><p class="tableblock">GET</p></td>
# <td class="tableblock halign-left valign-top" style="background-color: #FFFFFF;"><p class="tableblock"><a href="http://docs.opengeospatial.org/is/17-069r3/17-069r3.html#_declaration_of_conformance_classes">7.4 Declaration of conformance classes</a></p></td>
# </tr>
# <tr>
# <td class="tableblock halign-left valign-top" style="background-color: #FFFFFF;"><p class="tableblock">Feature collections</p></td>
# <td class="tableblock halign-left valign-top" style="background-color: #FFFFFF;"><p class="tableblock"><code>/collections</code></p></td>
# <td class="tableblock halign-left valign-top" style="background-color: #FFFFFF;"><p class="tableblock">GET</p></td>
# <td class="tableblock halign-left valign-top" style="background-color: #FFFFFF;"><p class="tableblock"><a href="http://docs.opengeospatial.org/is/17-069r3/17-069r3.html#_collections_">7.13 Feature collections</a></p></td>
# </tr>
# <tr>
# <td class="tableblock halign-left valign-top" style="background-color: #FFFFFF;"><p class="tableblock">Feature collection</p></td>
# <td class="tableblock halign-left valign-top" style="background-color: #FFFFFF;"><p class="tableblock"><code>/collections/{collectionId}</code></p></td>
# <td class="tableblock halign-left valign-top" style="background-color: #FFFFFF;"><p class="tableblock">GET</p></td>
# <td class="tableblock halign-left valign-top" style="background-color: #FFFFFF;"><p class="tableblock"><a href="http://docs.opengeospatial.org/is/17-069r3/17-069r3.html#_collection_">7.14 Feature collection</a></p></td>
# </tr>
# <tr>
# <td class="tableblock halign-left valign-top" style="background-color: #FFFFFF;"><p class="tableblock">Features</p></td>
# <td class="tableblock halign-left valign-top" style="background-color: #FFFFFF;"><p class="tableblock"><code>/collections/{collectionId}/items</code></p></td>
# <td class="tableblock halign-left valign-top" style="background-color: #FFFFFF;"><p class="tableblock">GET</p></td>
# <td class="tableblock halign-left valign-top" style="background-color: #FFFFFF;"><p class="tableblock"><a href="http://docs.opengeospatial.org/is/17-069r3/17-069r3.html#_items_">7.15 Features</a></p></td>
# </tr>
# <tr>
# <td class="tableblock halign-left valign-top" style="background-color: #FFFFFF;"><p class="tableblock">Feature</p></td>
# <td class="tableblock halign-left valign-top" style="background-color: #FFFFFF;"><p class="tableblock"><code>/collections/{collectionId}/items/{featureId}</code></p></td>
# <td class="tableblock halign-left valign-top" style="background-color: #FFFFFF;"><p class="tableblock">GET</p></td>
# <td class="tableblock halign-left valign-top" style="background-color: #FFFFFF;"><p class="tableblock"><a href="http://docs.opengeospatial.org/is/17-069r3/17-069r3.html#_feature_">7.16 Feature</a></p></td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ### What is STAC?

# %% [markdown]
# ### STAC Static Catalog
#
# - [STAC Spec](https://github.com/radiantearth/stac-spec)
#     - The SpatioTemporal Asset Catalog (STAC) specification aims to standardize the way geospatial assets are exposed online and queried.
#
# [STAC Catalog example](https://github.com/geotrellis/geotrellis-server/tree/develop/stac-example/catalog/landsat-stac-layers):
#
# **STAC Item**:
#
# ```json
# {
#   "type": "Feature",
#   "id": "LC80150322018141LGN00",
#   "stac_version" : "1.0.0-beta.1",
#   "stac_extensions" : [
#     "eo",
#     "view",
#     "proj",
#     "layer",
#     "https://example.com/stac/landsat-extension/1.0/schema.json"
#   ],
#   "bbox": [
#     -77.88298,
#     39.23073,
#     -75.07535,
#     41.41022
#   ],
#   "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#       [
#         [
#           -77.28911976020206,
#           41.40912394323429
#         ],
#         [
#           -75.07576783500748,
#           40.97162247589133
#         ],
#         [
#           -75.66872631473827,
#           39.23210949585851
#         ],
#         [
#           -77.87946700654118,
#           39.67679918442899
#         ],
#         [
#           -77.28911976020206,
#           41.40912394323429
#         ]
#       ]
#     ]
#   },
#   "collection": "landsat-8-l1",
#   "properties": {
#     "collection": "landsat-8-l1",
#     "layer:ids" : ["layer-us", "layer-pa"],
#     "datetime": "2018-05-21T15:44:59Z",
#     "view:sun_azimuth": 134.8082647,
#     "view:sun_elevation": 64.00406717,
#     "eo:cloud_cover": 4,
#     "landsat:row": "032",
#     "landsat:column": "015",
#     "landsat:product_id": "LC08_L1TP_015032_20180521_20180605_01_T1",
#     "landsat:scene_id": "LC80150322018141LGN00",
#     "landsat:processing_level": "L1TP",
#     "landsat:tier": "T1",
#     "proj:epsg": 32618,
#     "instruments": ["OLI_TIRS"],
#     "view:off_nadir": 0,
#     "platform": "landsat-8",
#     "gsd": 15
#   },
#   "assets": {
#     "index": {
#       "type": "text/html",
#       "title": "HTML index page",
#       "href": "https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/015/032/LC08_L1TP_015032_20180521_20180605_01_T1/index.html",
#       "roles": []
#     },
#     "thumbnail": {
#       "title": "Thumbnail image",
#       "type": "image/jpeg",
#       "href": "https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/015/032/LC08_L1TP_015032_20180521_20180605_01_T1/LC08_L1TP_015032_20180521_20180605_01_T1_thumb_large.jpg",
#       "roles" : [
#         "thumbnail"
#       ]
#     },
#     "B1": {
#       "type": "image/tiff",
#       "title": "Band 1 (coastal)",
#       "href": "https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/015/032/LC08_L1TP_015032_20180521_20180605_01_T1/LC08_L1TP_015032_20180521_20180605_01_T1_B1.TIF",
#       "roles": [],
#       "eo:bands": [
#         {
#           "name" : "B1",
#           "full_width_half_max" : 0.02,
#           "center_wavelength" : 0.44,
#           "common_name" : "coastal"
#         }
#       ]
#     },
#     "B2": {
#       "type": "image/tiff",
#       "title": "Band 2 (blue)",
#       "href": "https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/015/032/LC08_L1TP_015032_20180521_20180605_01_T1/LC08_L1TP_015032_20180521_20180605_01_T1_B2.TIF",
#       "roles": [],
#       "eo:bands": [
#         {
#           "name" : "B2",
#           "full_width_half_max" : 0.06,
#           "center_wavelength" : 0.48,
#           "common_name" : "blue"
#         }
#       ]
#     },
#     "B3": {
#       "type": "image/tiff",
#       "title": "Band 3 (green)",
#       "href": "https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/015/032/LC08_L1TP_015032_20180521_20180605_01_T1/LC08_L1TP_015032_20180521_20180605_01_T1_B3.TIF",
#       "roles": [],
#       "eo:bands": [
#         {
#           "name" : "B3",
#           "full_width_half_max" : 0.06,
#           "center_wavelength" : 0.56,
#           "common_name" : "green"
#         }
#       ]
#     },
#     "B4": {
#       "type": "image/tiff",
#       "title": "Band 4 (red)",
#       "href": "https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/015/032/LC08_L1TP_015032_20180521_20180605_01_T1/LC08_L1TP_015032_20180521_20180605_01_T1_B4.TIF",
#       "roles": [],
#       "eo:bands": [
#         {
#           "name" : "B4",
#           "full_width_half_max" : 0.04,
#           "center_wavelength" : 0.65,
#           "common_name" : "red"
#         }
#       ]
#     },
#     "B5": {
#       "type": "image/tiff",
#       "title": "Band 5 (nir)",
#       "href": "https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/015/032/LC08_L1TP_015032_20180521_20180605_01_T1/LC08_L1TP_015032_20180521_20180605_01_T1_B5.TIF",
#       "roles": [],
#       "eo:bands": [
#         {
#           "name" : "B5",
#           "full_width_half_max" : 0.03,
#           "center_wavelength" : 0.86,
#           "common_name" : "nir"
#         }
#       ]
#     },
#     "B6": {
#       "type": "image/tiff",
#       "title": "Band 6 (swir16)",
#       "href": "https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/015/032/LC08_L1TP_015032_20180521_20180605_01_T1/LC08_L1TP_015032_20180521_20180605_01_T1_B6.TIF",
#       "roles": [],
#       "eo:bands": [
#         {
#           "name" : "B6",
#           "full_width_half_max" : 0.08,
#           "center_wavelength" : 1.6,
#           "common_name" : "swir16"
#         }
#       ]
#     },
#     "B7": {
#       "type": "image/tiff",
#       "title": "Band 7 (swir22)",
#       "href": "https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/015/032/LC08_L1TP_015032_20180521_20180605_01_T1/LC08_L1TP_015032_20180521_20180605_01_T1_B7.TIF",
#       "roles": [],
#       "eo:bands": [
#         {
#           "name" : "B7",
#           "full_width_half_max" : 0.22,
#           "center_wavelength" : 2.2,
#           "common_name" : "swir22"
#         }
#       ]
#     },
#     "B8": {
#       "type": "image/tiff",
#       "title": "Band 8 (pan)",
#       "href": "https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/015/032/LC08_L1TP_015032_20180521_20180605_01_T1/LC08_L1TP_015032_20180521_20180605_01_T1_B8.TIF",
#       "roles": [],
#       "eo:bands": [
#         {
#           "name" : "B8",
#           "full_width_half_max" : 0.18,
#           "center_wavelength" : 0.59,
#           "common_name" : "pan"
#         }
#       ]
#     },
#     "B9": {
#       "type": "image/tiff",
#       "title": "Band 9 (cirrus)",
#       "href": "https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/015/032/LC08_L1TP_015032_20180521_20180605_01_T1/LC08_L1TP_015032_20180521_20180605_01_T1_B9.TIF",
#       "roles": [],
#       "eo:bands": [
#         {
#           "name" : "B9",
#           "full_width_half_max" : 0.02,
#           "center_wavelength" : 1.37,
#           "common_name" : "cirrus"
#         }
#       ]
#     },
#     "B10": {
#       "type": "image/tiff",
#       "title": "Band 10 (lwir)",
#       "href": "https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/015/032/LC08_L1TP_015032_20180521_20180605_01_T1/LC08_L1TP_015032_20180521_20180605_01_T1_B10.TIF",
#       "roles": [],
#       "eo:bands": [
#         {
#           "name" : "B10",
#           "full_width_half_max" : 0.8,
#           "center_wavelength" : 10.9,
#           "common_name" : "lwir11"
#         }
#       ]
#     },
#     "B11": {
#       "type": "image/tiff",
#       "title": "Band 11 (lwir)",
#       "href": "https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/015/032/LC08_L1TP_015032_20180521_20180605_01_T1/LC08_L1TP_015032_20180521_20180605_01_T1_B11.TIF",
#       "roles": [],
#       "eo:bands": [
#         {
#           "name" : "B11",
#           "full_width_half_max" : 1,
#           "center_wavelength" : 12,
#           "common_name" : "lwir2"
#         }
#       ]
#     },
#     "ANG": {
#       "title": "Angle coefficients file",
#       "type": "text/plain",
#       "href": "https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/015/032/LC08_L1TP_015032_20180521_20180605_01_T1/LC08_L1TP_015032_20180521_20180605_01_T1_ANG.txt",
#       "roles": []
#     },
#     "MTL": {
#       "title": "original metadata file",
#       "type": "text/plain",
#       "href": "https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/015/032/LC08_L1TP_015032_20180521_20180605_01_T1/LC08_L1TP_015032_20180521_20180605_01_T1_MTL.txt",
#       "roles": []
#     },
#     "BQA": {
#       "title": "Band quality data",
#       "type": "image/tiff",
#       "href": "https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/015/032/LC08_L1TP_015032_20180521_20180605_01_T1/LC08_L1TP_015032_20180521_20180605_01_T1_BQA.TIF",
#       "roles": []
#     }
#   },
#   "links": [
#     {
#       "rel": "self",
#       "href": "./LC80150322018141LGN00.json"
#     },
#     {
#       "rel": "parent",
#       "href": "../catalog.json"
#     },
#     {
#       "rel": "collection",
#       "href": "../catalog.json"
#     },
#     {
#       "rel": "root",
#       "href": "../../catalog.json"
#     }
#   ]
# }
# ```
#
# **STAC Collections**:
#
# ```json
# {
#   "stac_version" : "1.0.0-beta.1",
#   "stac_extensions" : [
#     "eo",
#     "view",
#     "https://example.com/stac/landsat-extension/1.0/schema.json"
#   ],
#   "id" : "landsat-8-l1",
#   "title" : "Landsat 8 L1",
#   "description" : "Landat 8 imagery radiometrically calibrated and orthorectified using gound points and Digital Elevation Model (DEM) data to correct relief displacement.",
#   "keywords" : [
#     "landsat",
#     "earth observation",
#     "usgs"
#   ],
#   "license" : "proprietary",
#   "providers" : [
#     {
#       "name" : "Development Seed",
#       "roles" : [
#         "processor"
#       ],
#       "url" : "https://github.com/sat-utils/sat-api"
#     }
#   ],
#   "extent" : {
#     "spatial" : {
#       "bbox" : [
#         [
#           -180.0,
#           -90.0,
#           180.0,
#           90.0
#         ]
#       ]
#     },
#     "temporal" : {
#       "interval" : [
#         [
#           "2018-05-01T00:00:00Z",
#           "2018-08-01T00:00:00Z"
#         ]
#       ]
#     }
#   },
#   "summaries": {},
#   "properties" : {
#     "collection" : "landsat-8-l1",
#     "instruments" : ["OLI_TIRS"],
#     "view:sun_azimuth" : 149.01607154,
#     "eo:bands" : [
#       {
#         "name" : "B1",
#         "full_width_half_max" : 0.02,
#         "center_wavelength" : 0.44,
#         "common_name" : "coastal"
#       },
#       {
#         "name" : "B2",
#         "full_width_half_max" : 0.06,
#         "center_wavelength" : 0.48,
#         "common_name" : "blue"
#       },
#       {
#         "name" : "B3",
#         "full_width_half_max" : 0.06,
#         "center_wavelength" : 0.56,
#         "common_name" : "green"
#       },
#       {
#         "name" : "B4",
#         "full_width_half_max" : 0.04,
#         "center_wavelength" : 0.65,
#         "common_name" : "red"
#       },
#       {
#         "name" : "B5",
#         "full_width_half_max" : 0.03,
#         "center_wavelength" : 0.86,
#         "common_name" : "nir"
#       },
#       {
#         "name" : "B6",
#         "full_width_half_max" : 0.08,
#         "center_wavelength" : 1.6,
#         "common_name" : "swir16"
#       },
#       {
#         "name" : "B7",
#         "full_width_half_max" : 0.22,
#         "center_wavelength" : 2.2,
#         "common_name" : "swir22"
#       },
#       {
#         "name" : "B8",
#         "full_width_half_max" : 0.18,
#         "center_wavelength" : 0.59,
#         "common_name" : "pan"
#       },
#       {
#         "name" : "B9",
#         "full_width_half_max" : 0.02,
#         "center_wavelength" : 1.37,
#         "common_name" : "cirrus"
#       },
#       {
#         "name" : "B10",
#         "full_width_half_max" : 0.8,
#         "center_wavelength" : 10.9,
#         "common_name" : "lwir11"
#       },
#       {
#         "name" : "B11",
#         "full_width_half_max" : 1,
#         "center_wavelength" : 12,
#         "common_name" : "lwir2"
#       }
#     ],
#     "view:off_nadir" : 0,
#     "view:azimuth" : 0,
#     "platform" : "landsat-8",
#     "gsd" : 15,
#     "view:sun_elevation" : 59.214247
#   },
#   "links" : [
#     {
#       "href" : "../catalog.json",
#       "rel" : "root"
#     },
#     {
#       "href" : "../catalog.json",
#       "rel" : "parent"
#     },
#     {
#       "href" : "./catalog.json",
#       "rel" : "self"
#     },
#     {
#       "href" : "./2018-06/LC80140332018166LGN00.json",
#       "rel" : "item"
#     },
#     {
#       "href" : "./2018-05/LC80150322018141LGN00.json",
#       "rel" : "item"
#     },
#     {
#       "href" : "./2018-07/LC80150332018189LGN00.json",
#       "rel" : "item"
#     },
#     {
#       "href" : "./2018-06/LC80300332018166LGN00.json",
#       "rel" : "item"
#     }
#   ]
# }
#
# ```
#
# **STAC Catalogs:**
#
# ```json
# {
#   "stac_version": "1.0.0-beta.1",
#   "stac_extensions": [],
#   "id": "landsat-stac-layers",
#   "title": "STAC for Landsat data",
#   "description": "STAC for Landsat data",
#   "links": [
#     {
#       "href": "./catalog.json",
#       "rel": "self"
#     },
#     {
#       "href": "./catalog.json",
#       "rel": "root"
#     },
#     {
#       "href": "./landsat-8-l1/catalog.json",
#       "rel": "child"
#     },
#     {
#       "href": "./layers/catalog.json",
#       "rel": "child"
#     }
#   ]
# }
# ```

# %% [markdown]
# ### STAC API

# %% [markdown]
# [STAC API](https://github.com/radiantearth/stac-api-spec) is an OGC Features API. Clients that work with OGC Features API will work with STAC API’s. STAC adds a bit of functionality that our users needed, mainly richer filtering, transactions, sorting, property names, versioning, and cross-collection search.
#
# If STAC Spec describes a static catalog and the static metadata representation, STAC API describes an API of a services that is responsibe for such metadata retrieval.
#
# [Website with the STAC Spec API documentation example](https://stacspec.org/STAC-api.html)
#
# We'll use [Franklin](https://azavea.github.io/franklin/) to demonstrate the STAC Catalog. Let's go through the Franklin demo and getting familiar with Franklin.
#
# * `GET | POST` `/collections/{collectionId}` [[link](http://localhost:9090/collections/landsat-8-l1)]
# * `GET | POST` `/collections/{collectionId}/items` [[link](http://localhost:9090/collections/landsat-8-l1/items)]
# * `GET | POST` `/collections/{collectionId}/items/{itemId}`[[link](http://localhost:9090/collections/landsat-8-l1/LC80150322018141LGN00)]

# %% [markdown]
# ### PyStac

# %%
# Install PyStac https://pystac.readthedocs.io/en/latest/
import sys
# !{sys.executable} -m pip install pystac pystac-io rasterio shapely s3-client
# Out:
# Requirement already satisfied: pystac in /opt/conda/lib/python3.8/site-packages (0.5.4)
# Requirement already satisfied: pystac-io in /opt/conda/lib/python3.8/site-packages (0.1.0)
# Requirement already satisfied: rasterio in /opt/conda/lib/python3.8/site-packages (1.2.0)
# Requirement already satisfied: shapely in /opt/conda/lib/python3.8/site-packages (1.7.1)
# Requirement already satisfied: s3-client in /opt/conda/lib/python3.8/site-packages (0.1.2)
# Requirement already satisfied: python-dateutil>=2.7.0 in /opt/conda/lib/python3.8/site-packages (from pystac) (2.8.1)
# Requirement already satisfied: click<8,>=4.0 in /opt/conda/lib/python3.8/site-packages (from rasterio) (7.1.2)
# Requirement already satisfied: attrs in /opt/conda/lib/python3.8/site-packages (from rasterio) (20.2.0)
# Requirement already satisfied: affine in /opt/conda/lib/python3.8/site-packages (from rasterio) (2.3.0)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/lib/python3.8/site-packages (from rasterio) (0.7.1)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.8/site-packages (from rasterio) (2020.6.20)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.8/site-packages (from rasterio) (1.19.5)
# Requirement already satisfied: snuggs>=1.4.1 in /opt/conda/lib/python3.8/site-packages (from rasterio) (1.4.7)
# Requirement already satisfied: click-plugins in /opt/conda/lib/python3.8/site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.8/site-packages (from s3-client) (0.8.7)
# Requirement already satisfied: boto3 in /opt/conda/lib/python3.8/site-packages (from s3-client) (1.16.62)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.8/site-packages (from s3-client) (1.25.10)
# Requirement already satisfied: botocore in /opt/conda/lib/python3.8/site-packages (from s3-client) (1.19.62)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.8/site-packages (from s3-client) (4.50.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.8/site-packages (from python-dateutil>=2.7.0->pystac) (1.15.0)
# Requirement already satisfied: pyparsing>=2.1.6 in /opt/conda/lib/python3.8/site-packages (from snuggs>=1.4.1->rasterio) (2.4.7)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/conda/lib/python3.8/site-packages (from boto3->s3-client) (0.10.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /opt/conda/lib/python3.8/site-packages (from boto3->s3-client) (0.3.4)

# %%
# Load a static catalog
from pystac import *

cat = Catalog.from_file('https://sentinel-stac.s3.amazonaws.com/catalog.json')

# catalog is lazy, lets crawl it
while len(cat.get_item_links()) == 0:
    print(f'Crawling through {cat}')
    cat = next(cat.get_children())
# Out:
# Crawling through <Catalog id=sentinel-stac>
# Crawling through <Collection id=sentinel-2-l1c>
# Crawling through <Catalog id=9>
# Crawling through <Catalog id=V>

# %%
import json

print(cat.description)
print(f'Contains {len(cat.get_item_links())} items.')
item = next(cat.get_items())
print(json.dumps(item.to_dict(), indent=2))
# Out:
# XK catalog
# Contains 388 items.
# {
#   "type": "Feature",
#   "stac_version": "1.0.0-beta.2",
#   "id": "S2B_9VXK_20171013_0",
#   "properties": {
#     "collection": "sentinel-2-l1c",
#     "datetime": "2017-10-13T20:03:46.461000Z",
#     "eo:cloud_cover": 41.52,
#     "sentinel:utm_zone": 9,
#     "sentinel:latitude_band": "V",
#     "sentinel:grid_square": "XK",
#     "sentinel:sequence": "0",
#     "sentinel:product_id": "S2B_MSIL1C_20171013T200349_N0205_R128_T09VXK_20171013T200346",
#     "eo:bands": [
#       {
#         "name": "B01",
#         "common_name": "coastal",
#         "gsd": 60.0,
#         "center_wavelength": 0.4439,
#         "full_width_half_max": 0.027
#       },
#       {
#         "name": "B02",
#         "common_name": "blue",
#         "gsd": 10.0,
#         "center_wavelength": 0.4966,
#         "full_width_half_max": 0.098
#       },
#       {
#         "name": "B03",
#         "common_name": "green",
#         "gsd": 10.0,
#         "center_wavelength": 0.56,
#         "full_width_half_max": 0.045
#       },
#       {
#         "name": "B04",
#         "common_name": "red",
#         "gsd": 10.0,
#         "center_wavelength": 0.6645,
#         "full_width_half_max": 0.038
#       },
#       {
#         "name": "B05",
#         "gsd": 20.0,
#         "center_wavelength": 0.7039,
#         "full_width_half_max": 0.019
#       },
#       {
#         "name": "B06",
#         "gsd": 20.0,
#         "center_wavelength": 0.7402,
#         "full_width_half_max": 0.018
#       },
#       {
#         "name": "B07",
#         "gsd": 20.0,
#         "center_wavelength": 0.7825,
#         "full_width_half_max": 0.028
#       },
#       {
#         "name": "B08",
#         "common_name": "nir",
#         "gsd": 10.0,
#         "center_wavelength": 0.8351,
#         "full_width_half_max": 0.145
#       },
#       {
#         "name": "B8A",
#         "gsd": 20.0,
#         "center_wavelength": 0.8648,
#         "full_width_half_max": 0.033
#       },
#       {
#         "name": "B09",
#         "gsd": 60.0,
#         "center_wavelength": 0.945,
#         "full_width_half_max": 0.026
#       },
#       {
#         "name": "B10",
#         "common_name": "cirrus",
#         "gsd": 60.0,
#         "center_wavelength": 1.3735,
#         "full_width_half_max": 0.075
#       },
#       {
#         "name": "B11",
#         "common_name": "swir16",
#         "gsd": 20.0,
#         "center_wavelength": 1.6137,
#         "full_width_half_max": 0.143
#       },
#       {
#         "name": "B12",
#         "common_name": "swir22",
#         "gsd": 20.0,
#         "center_wavelength": 2.22024,
#         "full_width_half_max": 0.242
#       }
#     ],
#     "platform": "sentinel-2b",
#     "instruments": [
#       "MSI"
#     ],
#     "view:off_nadir": 0,
#     "gsd": 10
#   },
#   "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#       [
#         [
#           -124.98134083358437,
#           62.08559605596175
#         ],
#         [
#           -127.08233512601228,
#           62.130709043745
#         ],
#         [
#           -127.01766656739149,
#           63.115660018589715
#         ],
#         [
#           -124.8461819572611,
#           63.068619032002935
#         ],
#         [
#           -124.98134083358437,
#           62.08559605596175
#         ]
#       ]
#     ]
#   },
#   "links": [
#     {
#       "rel": "root",
#       "href": "../../../../../catalog.json",
#       "type": "application/json"
#     },
#     {
#       "rel": "collection",
#       "href": "../../../../catalog.json"
#     },
#     {
#       "rel": "self",
#       "href": "https://sentinel-stac.s3.amazonaws.com/sentinel-2-l1c/9/V/XK/2017-10-13/S2B_9VXK_20171013_0.json",
#       "type": "application/json"
#     },
#     {
#       "rel": "parent",
#       "href": "../catalog.json",
#       "type": "application/json"
#     }
#   ],
#   "assets": {
#     "thumbnail": {
#       "href": "https://roda.sentinel-hub.com/sentinel-s2-l1c/tiles/9/V/XK/2017/10/13/0/preview.jpg",
#       "title": "Thumbnail"
#     },
#     "info": {
#       "href": "https://roda.sentinel-hub.com/sentinel-s2-l1c/tiles/9/V/XK/2017/10/13/0/tileInfo.json",
#       "title": "Basic JSON metadata"
#     },
#     "metadata": {
#       "href": "https://roda.sentinel-hub.com/sentinel-s2-l1c/tiles/9/V/XK/2017/10/13/0/metadata.xml",
#       "title": "Complete XML metadata"
#     },
#     "tki": {
#       "href": "https://sentinel-s2-l1c.s3.amazonaws.com/tiles/9/V/XK/2017/10/13/0/TKI.jp2",
#       "type": "image/jp2",
#       "title": "True color image",
#       "eo:bands": [
#         {
#           "name": "B04",
#           "common_name": "red",
#           "gsd": 10.0,
#           "center_wavelength": 0.6645,
#           "full_width_half_max": 0.038
#         },
#         {
#           "name": "B03",
#           "common_name": "green",
#           "gsd": 10.0,
#           "center_wavelength": 0.56,
#           "full_width_half_max": 0.045
#         },
#         {
#           "name": "B02",
#           "common_name": "blue",
#           "gsd": 10.0,
#           "center_wavelength": 0.4966,
#           "full_width_half_max": 0.098
#         }
#       ]
#     },
#     "B01": {
#       "href": "https://sentinel-s2-l1c.s3.amazonaws.com/tiles/9/V/XK/2017/10/13/0/B01.jp2",
#       "type": "image/jp2",
#       "title": "Band 1 (coastal)",
#       "eo:bands": [
#         {
#           "name": "B01",
#           "common_name": "coastal",
#           "gsd": 60.0,
#           "center_wavelength": 0.4439,
#           "full_width_half_max": 0.027
#         }
#       ]
#     },
#     "B02": {
#       "href": "https://sentinel-s2-l1c.s3.amazonaws.com/tiles/9/V/XK/2017/10/13/0/B02.jp2",
#       "type": "image/jp2",
#       "title": "Band 2 (blue)",
#       "eo:bands": [
#         {
#           "name": "B03",
#           "common_name": "green",
#           "gsd": 10.0,
#           "center_wavelength": 0.56,
#           "full_width_half_max": 0.045
#         }
#       ]
#     },
#     "B03": {
#       "href": "https://sentinel-s2-l1c.s3.amazonaws.com/tiles/9/V/XK/2017/10/13/0/B03.jp2",
#       "type": "image/jp2",
#       "title": "Band 3 (green)",
#       "eo:bands": [
#         {
#           "name": "B03",
#           "common_name": "green",
#           "gsd": 10.0,
#           "center_wavelength": 0.56,
#           "full_width_half_max": 0.045
#         }
#       ]
#     },
#     "B04": {
#       "href": "https://sentinel-s2-l1c.s3.amazonaws.com/tiles/9/V/XK/2017/10/13/0/B04.jp2",
#       "type": "image/jp2",
#       "title": "Band 4 (red)",
#       "eo:bands": [
#         {
#           "name": "B04",
#           "common_name": "red",
#           "gsd": 10.0,
#           "center_wavelength": 0.6645,
#           "full_width_half_max": 0.038
#         }
#       ]
#     },
#     "B05": {
#       "href": "https://sentinel-s2-l1c.s3.amazonaws.com/tiles/9/V/XK/2017/10/13/0/B05.jp2",
#       "type": "image/jp2",
#       "title": "Band 5",
#       "eo:bands": [
#         {
#           "name": "B05",
#           "gsd": 20.0,
#           "center_wavelength": 0.7039,
#           "full_width_half_max": 0.019
#         }
#       ]
#     },
#     "B06": {
#       "href": "https://sentinel-s2-l1c.s3.amazonaws.com/tiles/9/V/XK/2017/10/13/0/B06.jp2",
#       "type": "image/jp2",
#       "title": "Band 6",
#       "eo:bands": [
#         {
#           "name": "B06",
#           "gsd": 20.0,
#           "center_wavelength": 0.7402,
#           "full_width_half_max": 0.018
#         }
#       ]
#     },
#     "B07": {
#       "href": "https://sentinel-s2-l1c.s3.amazonaws.com/tiles/9/V/XK/2017/10/13/0/B07.jp2",
#       "type": "image/jp2",
#       "title": "Band 7",
#       "eo:bands": [
#         {
#           "name": "B07",
#           "gsd": 20.0,
#           "center_wavelength": 0.7825,
#           "full_width_half_max": 0.028
#         }
#       ]
#     },
#     "B08": {
#       "href": "https://sentinel-s2-l1c.s3.amazonaws.com/tiles/9/V/XK/2017/10/13/0/B08.jp2",
#       "type": "image/jp2",
#       "title": "Band 8 (nir)",
#       "eo:bands": [
#         {
#           "name": "B08",
#           "common_name": "nir",
#           "gsd": 10.0,
#           "center_wavelength": 0.8351,
#           "full_width_half_max": 0.145
#         }
#       ]
#     },
#     "B8A": {
#       "href": "https://sentinel-s2-l1c.s3.amazonaws.com/tiles/9/V/XK/2017/10/13/0/B08.jp2",
#       "type": "image/jp2",
#       "title": "Band 8A",
#       "eo:bands": [
#         {
#           "name": "B8A",
#           "gsd": 20.0,
#           "center_wavelength": 0.8648,
#           "full_width_half_max": 0.033
#         }
#       ]
#     },
#     "B09": {
#       "href": "https://sentinel-s2-l1c.s3.amazonaws.com/tiles/9/V/XK/2017/10/13/0/B09.jp2",
#       "type": "image/jp2",
#       "title": "Band 9",
#       "eo:bands": [
#         {
#           "name": "B09",
#           "gsd": 60.0,
#           "center_wavelength": 0.945,
#           "full_width_half_max": 0.026
#         }
#       ]
#     },
#     "B10": {
#       "href": "https://sentinel-s2-l1c.s3.amazonaws.com/tiles/9/V/XK/2017/10/13/0/B10.jp2",
#       "type": "image/jp2",
#       "title": "Band 10 (cirrus)",
#       "eo:bands": [
#         {
#           "name": "B10",
#           "common_name": "cirrus",
#           "gsd": 60.0,
#           "center_wavelength": 1.3735,
#           "full_width_half_max": 0.075
#         }
#       ]
#     },
#     "B11": {
#       "href": "https://sentinel-s2-l1c.s3.amazonaws.com/tiles/9/V/XK/2017/10/13/0/B11.jp2",
#       "type": "image/jp2",
#       "title": "Band 11 (swir16)",
#       "eo:bands": [
#         {
#           "name": "B11",
#           "common_name": "swir16",
#           "gsd": 20.0,
#           "center_wavelength": 1.6137,
#           "full_width_half_max": 0.143
#         }
#       ]
#     },
#     "B12": {
#       "href": "https://sentinel-s2-l1c.s3.amazonaws.com/tiles/9/V/XK/2017/10/13/0/B11.jp2",
#       "type": "image/jp2",
#       "title": "Band 12 (swir22)",
#       "eo:bands": [
#         {
#           "name": "B12",
#           "common_name": "swir22",
#           "gsd": 20.0,
#           "center_wavelength": 2.22024,
#           "full_width_half_max": 0.242
#         }
#       ]
#     }
#   },
#   "bbox": [
#     -127.08233512601228,
#     62.08559605596175,
#     -124.8461819572611,
#     63.115660018589715
#   ],
#   "stac_extensions": [
#     "eo",
#     "view"
#   ]
# }

# %%
import rasterio
from shapely.geometry import Polygon, mapping, shape
from urllib.parse import urlparse
import os
from pathlib import Path

# define a function that will allow us to collect TIFF spatial data
def get_bbox_and_footprint(raster_uri):
    with rasterio.open(raster_uri) as ds:
        bounds = ds.bounds
        bbox = [bounds.left, bounds.bottom, bounds.right, bounds.top]
        footprint = Polygon([
            [bounds.left, bounds.bottom],
            [bounds.left, bounds.top],
            [bounds.right, bounds.top],
            [bounds.right, bounds.bottom]
        ])

        return (bbox, mapping(footprint))

def get_id(uri):
    parsed_uri = urlparse(uri)
    # extract a filename but wihtout extention
    return Path(os.path.basename(parsed_uri.path)).stem
    
# function to get the original scene URI by its COG URI
def get_elevation_tile_uri(uri):
    item_id = get_id(uri)
    key_col, key_row = item_id.split('_')[1].split('-')
    
    col = int(key_col) - 180
    def get_long(col):
        if(col >= 0):
            return f'E{col:03d}'
        else:
            return f'W{-col:03d}'
    long = get_long(col)
    
    row = 89 - int(key_row)
    def get_lat(row):
        if(row >= 0):
            return f'N{row:02d}'
        else:
            return f'S{-row:02d}'
    lat = get_lat(row)

    return f's3://elevation-tiles-prod/v2/skadi/{lat}/{lat}{long}.hgt.gz'

# %%
import boto3

s3 = boto3.resource('s3')
catalog_bucket = s3.Bucket('geotrellis-workshop')

uris = [
    f's3://geotrellis-workshop/{tiff.key}' for tiff in catalog_bucket.objects.filter(Prefix='shade-out').all() 
        if tiff.key.endswith('.tif')
]
len(uris)
# Out:
# 1797

# %%
from datetime import datetime, timezone
import os
from pathlib import Path
from functools import reduce

# Create a catalog
catalog = Catalog(id='shade-out-catalog', description='Hillshade Buffered GeoTrellis Catalog.')

# it is empty
print(list(catalog.get_children()))
print(list(catalog.get_items()))

uris_aoi = uris

# compute collection spatial extent
footprints = [get_bbox_and_footprint(uri)[1] for uri in uris_aoi]
unioned_footprint = reduce(lambda l, r: shape(l).union(shape(r)), footprints)
collection_bbox = list(unioned_footprint.bounds)
spatial_extent = SpatialExtent(bboxes=[collection_bbox])

# pretend we know the temporal extent
temporal_extent = TemporalExtent(intervals=[datetime(2020, 12, 1, tzinfo=timezone.utc), datetime(2021, 2, 1, tzinfo=timezone.utc)])
collection_extent = Extent(spatial=spatial_extent, temporal=temporal_extent)

collection = Collection(
    id='hillshade-buffered',
    description='Hillshade Buffered GeoTrellis Collection.',
    extent=collection_extent,
    license='proprietary'
)

for uri in uris_aoi:
    print(f'Processing {uri}')
    bbox, footprint = get_bbox_and_footprint(uri)
    # get item id from the uri
    item_id = get_id(uri)
    # compute elevation uri from the given uri
    elevation_uri = get_elevation_tile_uri(uri)

    item = Item(
        id=item_id,
        geometry=footprint,
        bbox=bbox,
        datetime=datetime.utcnow(),
        properties={}
    )
    # add item assets
    item.add_asset(
        key='cog',
        asset=Asset(
            href=uri,
            media_type=MediaType.GEOTIFF
        )
    )

    item.add_asset(
        key='source',
        asset=Asset(
            href=elevation_uri,
            media_type='application/gzip'
        )
    )

    # add item into the catalog
    collection.add_item(item)

catalog.add_child(collection)

print(collection.to_dict())
print(catalog.describe())

# print(next(collection.get_items()).to_dict())

catalog.normalize_hrefs('s3://geotrellis-workshop/shade-out-catalog-absolute/')

print(json.dumps(catalog.to_dict(), indent=2))

# Save catalog
# Use PyStacIO to save catalog to S3
import pystac_io
import pystac_io.s3

pystac_io.register('s3')
# Reference to catalog types
# https://github.com/stac-utils/pystac/blob/v0.5.4/pystac/catalog.py#L13-L39
# CatalogType.SELF_CONTAINED
catalog.save(catalog_type=CatalogType.ABSOLUTE_PUBLISHED)
# Out:
# []
# []
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_100-35.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_100-36.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_100-37.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_100-38.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_100-39.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_100-40.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_100-41.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_100-42.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_100-43.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_100-44.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_100-45.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_100-46.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_100-47.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_100-48.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_100-51.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_100-52.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_100-53.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_100-54.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_100-57.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_100-58.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_100-59.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_100-60.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_100-61.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_100-62.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_100-63.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_100-64.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_100-65.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_101-35.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_101-36.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_101-37.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_101-38.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_101-39.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_101-40.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_101-41.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_101-42.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_101-43.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_101-44.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_101-45.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_101-46.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_101-47.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_101-48.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_101-51.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_101-52.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_101-53.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_101-54.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_101-55.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_101-56.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_101-57.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_101-58.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_101-59.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_101-60.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_101-61.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_101-62.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_101-63.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_101-64.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_101-65.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_102-35.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_102-36.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_102-37.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_102-38.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_102-39.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_102-40.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_102-41.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_102-42.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_102-43.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_102-44.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_102-45.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_102-46.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_102-47.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_102-48.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_102-53.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_102-55.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_102-56.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_102-57.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_102-58.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_102-59.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_102-60.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_102-61.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_102-62.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_102-63.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_102-64.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_102-65.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_103-35.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_103-36.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_103-37.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_103-38.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_103-39.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_103-40.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_103-41.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_103-42.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_103-43.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_103-44.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_103-45.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_103-46.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_103-47.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_103-54.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_103-55.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_103-56.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_103-57.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_103-58.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_103-59.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_103-60.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_103-61.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_103-62.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_103-63.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_103-64.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_103-65.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_104-35.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_104-36.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_104-37.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_104-38.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_104-39.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_104-40.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_104-41.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_104-42.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_104-43.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_104-44.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_104-45.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_104-46.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_104-47.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_104-52.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_104-53.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_104-54.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_104-55.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_104-56.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_104-57.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_104-58.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_104-59.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_104-60.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_104-61.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_104-62.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_104-63.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_104-64.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_104-65.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_105-35.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_105-36.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_105-37.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_105-38.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_105-39.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_105-40.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_105-41.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_105-42.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_105-43.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_105-44.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_105-45.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_105-46.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_105-47.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_105-48.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_105-51.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_105-52.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_105-53.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_105-55.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_105-56.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_105-57.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_105-58.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_105-59.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_105-60.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_105-61.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_105-62.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_105-63.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_105-64.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_105-65.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-35.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-36.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-37.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-38.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-39.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-40.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-41.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-42.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-43.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-44.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-45.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-46.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-47.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-48.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-49.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-50.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-51.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-52.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-53.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-54.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-55.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-56.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-57.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-58.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-59.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-60.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-61.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-62.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-63.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-64.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_106-65.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-35.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-36.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-37.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-38.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-39.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-40.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-41.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-42.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-43.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-44.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-45.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-46.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-47.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-48.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-49.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-50.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-51.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-52.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-53.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-54.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-55.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-56.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-57.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-58.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-59.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-60.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-61.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-62.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-63.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-64.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_107-65.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-35.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-36.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-37.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-38.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-39.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-40.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-41.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-42.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-43.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-44.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-45.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-46.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-47.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-48.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-49.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-50.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-51.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-52.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-53.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-54.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-55.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-56.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-57.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-58.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-59.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-60.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-61.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-62.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-63.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-64.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_108-65.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_109-35.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_109-36.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_109-37.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_109-38.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_109-39.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_109-40.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_109-41.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_109-42.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_109-43.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_109-44.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_109-45.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_109-47.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_109-48.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_109-49.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_109-50.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_109-51.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_109-52.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_109-53.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_109-54.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_109-55.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_109-56.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_109-57.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_109-58.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_109-59.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_109-60.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_109-61.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_109-62.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_109-63.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_109-64.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_109-65.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-35.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-36.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-37.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-38.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-39.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-40.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-41.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-42.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-43.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-44.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-45.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-46.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-47.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-48.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-49.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-50.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-51.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-52.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-53.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-54.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-55.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-56.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-57.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-58.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-59.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-60.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-61.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-62.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-63.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-64.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_110-65.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-35.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-36.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-37.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-38.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-39.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-40.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-41.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-42.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-43.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-44.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-45.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-46.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-47.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-48.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-49.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-50.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-51.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-52.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-53.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-54.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-55.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-56.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-57.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-58.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-59.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-60.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-61.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-62.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-63.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-64.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_111-65.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-35.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-36.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-37.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-38.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-39.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-40.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-41.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-42.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-43.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-44.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-45.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-46.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-47.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-48.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-49.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-50.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-51.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-52.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-53.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-54.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-55.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-56.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-57.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-58.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-59.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-60.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-61.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-62.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-63.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-64.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_112-65.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-35.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-36.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-37.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-38.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-39.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-40.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-41.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-42.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-43.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-44.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-45.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-46.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-47.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-48.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-49.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-50.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-51.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-52.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-53.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-54.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-55.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-56.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-57.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-58.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-59.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-60.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-61.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-62.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-63.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-64.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_113-65.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-35.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-36.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-37.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-38.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-39.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-40.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-41.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-42.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-43.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-44.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-45.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-46.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-47.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-48.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-49.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-50.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-51.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-52.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-53.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-54.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-55.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-56.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-57.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-58.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-59.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-60.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-61.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-62.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-63.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-64.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_114-65.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-35.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-36.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-37.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-38.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-39.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-40.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-41.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-42.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-43.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-44.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-45.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-46.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-47.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-48.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-49.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-50.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-51.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-52.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-53.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-54.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-55.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-56.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-57.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-58.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-59.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-60.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-61.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-62.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-63.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-64.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_115-65.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-35.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-36.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-37.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-38.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-39.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-40.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-41.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-42.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-43.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-44.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-45.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-46.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-47.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-48.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-49.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-50.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-51.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-52.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-53.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-54.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-55.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-56.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-57.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-58.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-59.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-60.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-61.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-62.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-63.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-64.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_54-65.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-35.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-36.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-37.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-38.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-39.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-40.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-41.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-42.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-43.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-44.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-45.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-46.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-47.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-48.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-49.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-50.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-51.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-52.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-53.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-54.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-55.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-56.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-57.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-58.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-59.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-60.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-61.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-62.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-63.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-64.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_55-65.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_56-35.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_56-36.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_56-37.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_56-38.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_56-39.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_56-40.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_56-41.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_56-42.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_56-46.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_56-47.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_56-48.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_56-49.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_56-50.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_56-51.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_56-52.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_56-53.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_56-54.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_56-55.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_56-56.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_56-57.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_56-58.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_56-59.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_56-60.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_56-61.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_56-62.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_56-63.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_56-64.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_56-65.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_57-35.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_57-36.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_57-37.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_57-38.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_57-39.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_57-40.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_57-45.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_57-46.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_57-47.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_57-48.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_57-49.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_57-50.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_57-53.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_57-54.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_57-55.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_57-56.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_57-57.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_57-58.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_57-59.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_57-60.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_57-61.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_57-62.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_57-63.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_57-64.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_57-65.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_58-35.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_58-36.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_58-37.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_58-38.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_58-39.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_58-40.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_58-41.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_58-42.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_58-43.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_58-44.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_58-45.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_58-46.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_58-48.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_58-49.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_58-50.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_58-51.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_58-53.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_58-54.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_58-55.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_58-56.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_58-57.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_58-58.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_58-59.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_58-60.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_58-61.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_58-62.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_58-63.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_58-64.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_58-65.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_59-35.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_59-36.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_59-37.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_59-38.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_59-39.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_59-40.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_59-41.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_59-42.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_59-43.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_59-44.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_59-45.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_59-46.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_59-47.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_59-48.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_59-49.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_59-50.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_59-51.tif
# Processing s3://geotrellis-workshop/shade-out/hillshade-buffered_59-52.tif
# ...
#       * <Item id=hillshade-buffered_86-55>
#       * <Item id=hillshade-buffered_86-56>
#       * <Item id=hillshade-buffered_86-59>
#       * <Item id=hillshade-buffered_86-60>
#       * <Item id=hillshade-buffered_86-61>
#       * <Item id=hillshade-buffered_86-62>
#       * <Item id=hillshade-buffered_86-63>
#       * <Item id=hillshade-buffered_86-64>
#       * <Item id=hillshade-buffered_86-65>
#       * <Item id=hillshade-buffered_87-35>
#       * <Item id=hillshade-buffered_87-36>
#       * <Item id=hillshade-buffered_87-37>
#       * <Item id=hillshade-buffered_87-38>
#       * <Item id=hillshade-buffered_87-39>
#       * <Item id=hillshade-buffered_87-40>
#       * <Item id=hillshade-buffered_87-41>
#       * <Item id=hillshade-buffered_87-42>
#       * <Item id=hillshade-buffered_87-43>
#       * <Item id=hillshade-buffered_87-44>
#       * <Item id=hillshade-buffered_87-45>
#       * <Item id=hillshade-buffered_87-46>
#       * <Item id=hillshade-buffered_87-47>
#       * <Item id=hillshade-buffered_87-51>
#       * <Item id=hillshade-buffered_87-52>
#       * <Item id=hillshade-buffered_87-53>
#       * <Item id=hillshade-buffered_87-54>
#       * <Item id=hillshade-buffered_87-55>
#       * <Item id=hillshade-buffered_87-56>
#       * <Item id=hillshade-buffered_87-57>
#       * <Item id=hillshade-buffered_87-58>
#       * <Item id=hillshade-buffered_87-59>
#       * <Item id=hillshade-buffered_87-60>
#       * <Item id=hillshade-buffered_87-61>
#       * <Item id=hillshade-buffered_87-62>
#       * <Item id=hillshade-buffered_87-63>
#       * <Item id=hillshade-buffered_87-64>
#       * <Item id=hillshade-buffered_87-65>
#       * <Item id=hillshade-buffered_88-35>
#       * <Item id=hillshade-buffered_88-36>
#       * <Item id=hillshade-buffered_88-37>
#       * <Item id=hillshade-buffered_88-38>
#       * <Item id=hillshade-buffered_88-39>
#       * <Item id=hillshade-buffered_88-40>
#       * <Item id=hillshade-buffered_88-41>
#       * <Item id=hillshade-buffered_88-42>
#       * <Item id=hillshade-buffered_88-43>
#       * <Item id=hillshade-buffered_88-44>
#       * <Item id=hillshade-buffered_88-45>
#       * <Item id=hillshade-buffered_88-49>
#       * <Item id=hillshade-buffered_88-50>
#       * <Item id=hillshade-buffered_88-52>
#       * <Item id=hillshade-buffered_88-53>
#       * <Item id=hillshade-buffered_88-54>
#       * <Item id=hillshade-buffered_88-55>
#       * <Item id=hillshade-buffered_88-58>
#       * <Item id=hillshade-buffered_88-59>
#       * <Item id=hillshade-buffered_88-61>
#       * <Item id=hillshade-buffered_88-62>
#       * <Item id=hillshade-buffered_88-63>
#       * <Item id=hillshade-buffered_88-64>
#       * <Item id=hillshade-buffered_88-65>
#       * <Item id=hillshade-buffered_89-35>
#       * <Item id=hillshade-buffered_89-36>
#       * <Item id=hillshade-buffered_89-37>
#       * <Item id=hillshade-buffered_89-38>
#       * <Item id=hillshade-buffered_89-39>
#       * <Item id=hillshade-buffered_89-40>
#       * <Item id=hillshade-buffered_89-41>
#       * <Item id=hillshade-buffered_89-42>
#       * <Item id=hillshade-buffered_89-43>
#       * <Item id=hillshade-buffered_89-44>
#       * <Item id=hillshade-buffered_89-45>
#       * <Item id=hillshade-buffered_89-46>
#       * <Item id=hillshade-buffered_89-47>
#       * <Item id=hillshade-buffered_89-49>
#       * <Item id=hillshade-buffered_89-50>
#       * <Item id=hillshade-buffered_89-52>
#       * <Item id=hillshade-buffered_89-54>
#       * <Item id=hillshade-buffered_89-57>
#       * <Item id=hillshade-buffered_89-58>
#       * <Item id=hillshade-buffered_89-61>
#       * <Item id=hillshade-buffered_89-62>
#       * <Item id=hillshade-buffered_89-63>
#       * <Item id=hillshade-buffered_89-64>
#       * <Item id=hillshade-buffered_89-65>
#       * <Item id=hillshade-buffered_90-35>
#       * <Item id=hillshade-buffered_90-36>
#       * <Item id=hillshade-buffered_90-37>
#       * <Item id=hillshade-buffered_90-38>
#       * <Item id=hillshade-buffered_90-39>
#       * <Item id=hillshade-buffered_90-40>
#       * <Item id=hillshade-buffered_90-41>
#       * <Item id=hillshade-buffered_90-42>
#       * <Item id=hillshade-buffered_90-43>
#       * <Item id=hillshade-buffered_90-44>
#       * <Item id=hillshade-buffered_90-45>
#       * <Item id=hillshade-buffered_90-46>
#       * <Item id=hillshade-buffered_90-47>
#       * <Item id=hillshade-buffered_90-48>
#       * <Item id=hillshade-buffered_90-49>
#       * <Item id=hillshade-buffered_90-50>
#       * <Item id=hillshade-buffered_90-51>
#       * <Item id=hillshade-buffered_90-52>
#       * <Item id=hillshade-buffered_90-53>
#       * <Item id=hillshade-buffered_90-54>
#       * <Item id=hillshade-buffered_90-56>
#       * <Item id=hillshade-buffered_90-57>
#       * <Item id=hillshade-buffered_90-58>
#       * <Item id=hillshade-buffered_90-61>
#       * <Item id=hillshade-buffered_90-62>
#       * <Item id=hillshade-buffered_90-63>
#       * <Item id=hillshade-buffered_90-64>
#       * <Item id=hillshade-buffered_90-65>
#       * <Item id=hillshade-buffered_91-35>
#       * <Item id=hillshade-buffered_91-36>
#       * <Item id=hillshade-buffered_91-37>
#       * <Item id=hillshade-buffered_91-38>
#       * <Item id=hillshade-buffered_91-39>
#       * <Item id=hillshade-buffered_91-40>
#       * <Item id=hillshade-buffered_91-41>
#       * <Item id=hillshade-buffered_91-42>
#       * <Item id=hillshade-buffered_91-43>
#       * <Item id=hillshade-buffered_91-44>
#       * <Item id=hillshade-buffered_91-45>
#       * <Item id=hillshade-buffered_91-46>
#       * <Item id=hillshade-buffered_91-47>
#       * <Item id=hillshade-buffered_91-48>
#       * <Item id=hillshade-buffered_91-49>
#       * <Item id=hillshade-buffered_91-50>
#       * <Item id=hillshade-buffered_91-51>
#       * <Item id=hillshade-buffered_91-52>
#       * <Item id=hillshade-buffered_91-53>
#       * <Item id=hillshade-buffered_91-54>
#       * <Item id=hillshade-buffered_91-55>
#       * <Item id=hillshade-buffered_91-56>
#       * <Item id=hillshade-buffered_91-57>
#       * <Item id=hillshade-buffered_91-58>
#       * <Item id=hillshade-buffered_91-60>
#       * <Item id=hillshade-buffered_91-61>
#       * <Item id=hillshade-buffered_91-62>
#       * <Item id=hillshade-buffered_91-63>
#       * <Item id=hillshade-buffered_91-64>
#       * <Item id=hillshade-buffered_91-65>
#       * <Item id=hillshade-buffered_92-35>
#       * <Item id=hillshade-buffered_92-36>
#       * <Item id=hillshade-buffered_92-37>
#       * <Item id=hillshade-buffered_92-38>
#       * <Item id=hillshade-buffered_92-39>
#       * <Item id=hillshade-buffered_92-40>
#       * <Item id=hillshade-buffered_92-41>
#       * <Item id=hillshade-buffered_92-42>
#       * <Item id=hillshade-buffered_92-43>
#       * <Item id=hillshade-buffered_92-44>
#       * <Item id=hillshade-buffered_92-45>
#       * <Item id=hillshade-buffered_92-46>
#       * <Item id=hillshade-buffered_92-47>
#       * <Item id=hillshade-buffered_92-48>
#       * <Item id=hillshade-buffered_92-49>
#       * <Item id=hillshade-buffered_92-50>
#       * <Item id=hillshade-buffered_92-51>
#       * <Item id=hillshade-buffered_92-52>
#       * <Item id=hillshade-buffered_92-53>
#       * <Item id=hillshade-buffered_92-54>
#       * <Item id=hillshade-buffered_92-55>
#       * <Item id=hillshade-buffered_92-56>
#       * <Item id=hillshade-buffered_92-57>
#       * <Item id=hillshade-buffered_92-58>
#       * <Item id=hillshade-buffered_92-60>
#       * <Item id=hillshade-buffered_92-61>
#       * <Item id=hillshade-buffered_92-62>
#       * <Item id=hillshade-buffered_92-63>
#       * <Item id=hillshade-buffered_92-64>
#       * <Item id=hillshade-buffered_92-65>
#       * <Item id=hillshade-buffered_93-35>
#       * <Item id=hillshade-buffered_93-36>
#       * <Item id=hillshade-buffered_93-37>
#       * <Item id=hillshade-buffered_93-38>
#       * <Item id=hillshade-buffered_93-39>
#       * <Item id=hillshade-buffered_93-40>
#       * <Item id=hillshade-buffered_93-41>
#       * <Item id=hillshade-buffered_93-42>
#       * <Item id=hillshade-buffered_93-43>
#       * <Item id=hillshade-buffered_93-44>
#       * <Item id=hillshade-buffered_93-45>
#       * <Item id=hillshade-buffered_93-46>
#       * <Item id=hillshade-buffered_93-47>
#       * <Item id=hillshade-buffered_93-50>
#       * <Item id=hillshade-buffered_93-52>
#       * <Item id=hillshade-buffered_93-53>
#       * <Item id=hillshade-buffered_93-54>
#       * <Item id=hillshade-buffered_93-55>
#       * <Item id=hillshade-buffered_93-56>
#       * <Item id=hillshade-buffered_93-57>
#       * <Item id=hillshade-buffered_93-58>
#       * <Item id=hillshade-buffered_93-60>
#       * <Item id=hillshade-buffered_93-61>
#       * <Item id=hillshade-buffered_93-62>
#       * <Item id=hillshade-buffered_93-63>
#       * <Item id=hillshade-buffered_93-64>
#       * <Item id=hillshade-buffered_93-65>
#       * <Item id=hillshade-buffered_94-35>
#       * <Item id=hillshade-buffered_94-36>
#       * <Item id=hillshade-buffered_94-37>
#       * <Item id=hillshade-buffered_94-38>
#       * <Item id=hillshade-buffered_94-39>
#       * <Item id=hillshade-buffered_94-40>
#       * <Item id=hillshade-buffered_94-41>
#       * <Item id=hillshade-buffered_94-42>
#       * <Item id=hillshade-buffered_94-43>
#       * <Item id=hillshade-buffered_94-44>
#       * <Item id=hillshade-buffered_94-45>
#       * <Item id=hillshade-buffered_94-46>
#       * <Item id=hillshade-buffered_94-47>
#       * <Item id=hillshade-buffered_94-49>
#       * <Item id=hillshade-buffered_94-50>
#       * <Item id=hillshade-buffered_94-51>
#       * <Item id=hillshade-buffered_94-52>
#       * <Item id=hillshade-buffered_94-53>
#       * <Item id=hillshade-buffered_94-54>
#       * <Item id=hillshade-buffered_94-55>
#       * <Item id=hillshade-buffered_94-56>
#       * <Item id=hillshade-buffered_94-57>
#       * <Item id=hillshade-buffered_94-58>
#       * <Item id=hillshade-buffered_94-60>
#       * <Item id=hillshade-buffered_94-61>
#       * <Item id=hillshade-buffered_94-62>
#       * <Item id=hillshade-buffered_94-63>
#       * <Item id=hillshade-buffered_94-64>
#       * <Item id=hillshade-buffered_94-65>
#       * <Item id=hillshade-buffered_95-35>
#       * <Item id=hillshade-buffered_95-36>
#       * <Item id=hillshade-buffered_95-37>
#       * <Item id=hillshade-buffered_95-38>
#       * <Item id=hillshade-buffered_95-39>
#       * <Item id=hillshade-buffered_95-40>
#       * <Item id=hillshade-buffered_95-41>
#       * <Item id=hillshade-buffered_95-42>
#       * <Item id=hillshade-buffered_95-43>
#       * <Item id=hillshade-buffered_95-44>
#       * <Item id=hillshade-buffered_95-45>
#       * <Item id=hillshade-buffered_95-46>
#       * <Item id=hillshade-buffered_95-49>
#       * <Item id=hillshade-buffered_95-50>
#       * <Item id=hillshade-buffered_95-51>
#       * <Item id=hillshade-buffered_95-52>
#       * <Item id=hillshade-buffered_95-53>
#       * <Item id=hillshade-buffered_95-54>
#       * <Item id=hillshade-buffered_95-55>
#       * <Item id=hillshade-buffered_95-56>
#       * <Item id=hillshade-buffered_95-57>
#       * <Item id=hillshade-buffered_95-58>
#       * <Item id=hillshade-buffered_95-60>
#       * <Item id=hillshade-buffered_95-62>
#       * <Item id=hillshade-buffered_95-63>
#       * <Item id=hillshade-buffered_95-64>
#       * <Item id=hillshade-buffered_95-65>
#       * <Item id=hillshade-buffered_96-35>
#       * <Item id=hillshade-buffered_96-36>
#       * <Item id=hillshade-buffered_96-37>
#       * <Item id=hillshade-buffered_96-38>
#       * <Item id=hillshade-buffered_96-39>
#       * <Item id=hillshade-buffered_96-40>
#       * <Item id=hillshade-buffered_96-41>
#       * <Item id=hillshade-buffered_96-42>
#       * <Item id=hillshade-buffered_96-43>
#       * <Item id=hillshade-buffered_96-44>
#       * <Item id=hillshade-buffered_96-45>
#       * <Item id=hillshade-buffered_96-46>
#       * <Item id=hillshade-buffered_96-48>
#       * <Item id=hillshade-buffered_96-50>
#       * <Item id=hillshade-buffered_96-51>
#       * <Item id=hillshade-buffered_96-52>
#       * <Item id=hillshade-buffered_96-53>
#       * <Item id=hillshade-buffered_96-56>
#       * <Item id=hillshade-buffered_96-57>
#       * <Item id=hillshade-buffered_96-58>
#       * <Item id=hillshade-buffered_96-60>
#       * <Item id=hillshade-buffered_96-61>
#       * <Item id=hillshade-buffered_96-62>
#       * <Item id=hillshade-buffered_96-63>
#       * <Item id=hillshade-buffered_96-64>
#       * <Item id=hillshade-buffered_96-65>
#       * <Item id=hillshade-buffered_97-35>
#       * <Item id=hillshade-buffered_97-36>
#       * <Item id=hillshade-buffered_97-37>
#       * <Item id=hillshade-buffered_97-38>
#       * <Item id=hillshade-buffered_97-39>
#       * <Item id=hillshade-buffered_97-40>
#       * <Item id=hillshade-buffered_97-41>
#       * <Item id=hillshade-buffered_97-42>
#       * <Item id=hillshade-buffered_97-43>
#       * <Item id=hillshade-buffered_97-44>
#       * <Item id=hillshade-buffered_97-45>
#       * <Item id=hillshade-buffered_97-46>
#       * <Item id=hillshade-buffered_97-47>
#       * <Item id=hillshade-buffered_97-48>
#       * <Item id=hillshade-buffered_97-49>
#       * <Item id=hillshade-buffered_97-50>
#       * <Item id=hillshade-buffered_97-52>
#       * <Item id=hillshade-buffered_97-53>
#       * <Item id=hillshade-buffered_97-54>
#       * <Item id=hillshade-buffered_97-55>
#       * <Item id=hillshade-buffered_97-56>
#       * <Item id=hillshade-buffered_97-57>
#       * <Item id=hillshade-buffered_97-58>
#       * <Item id=hillshade-buffered_97-63>
#       * <Item id=hillshade-buffered_97-64>
#       * <Item id=hillshade-buffered_97-65>
#       * <Item id=hillshade-buffered_98-35>
#       * <Item id=hillshade-buffered_98-36>
#       * <Item id=hillshade-buffered_98-37>
#       * <Item id=hillshade-buffered_98-38>
#       * <Item id=hillshade-buffered_98-39>
#       * <Item id=hillshade-buffered_98-40>
#       * <Item id=hillshade-buffered_98-41>
#       * <Item id=hillshade-buffered_98-42>
#       * <Item id=hillshade-buffered_98-43>
#       * <Item id=hillshade-buffered_98-44>
#       * <Item id=hillshade-buffered_98-45>
#       * <Item id=hillshade-buffered_98-46>
#       * <Item id=hillshade-buffered_98-47>
#       * <Item id=hillshade-buffered_98-48>
#       * <Item id=hillshade-buffered_98-49>
#       * <Item id=hillshade-buffered_98-51>
#       * <Item id=hillshade-buffered_98-52>
#       * <Item id=hillshade-buffered_98-53>
#       * <Item id=hillshade-buffered_98-57>
#       * <Item id=hillshade-buffered_98-64>
#       * <Item id=hillshade-buffered_98-65>
#       * <Item id=hillshade-buffered_99-35>
#       * <Item id=hillshade-buffered_99-36>
#       * <Item id=hillshade-buffered_99-37>
#       * <Item id=hillshade-buffered_99-38>
#       * <Item id=hillshade-buffered_99-39>
#       * <Item id=hillshade-buffered_99-40>
#       * <Item id=hillshade-buffered_99-41>
#       * <Item id=hillshade-buffered_99-42>
#       * <Item id=hillshade-buffered_99-43>
#       * <Item id=hillshade-buffered_99-44>
#       * <Item id=hillshade-buffered_99-45>
#       * <Item id=hillshade-buffered_99-46>
#       * <Item id=hillshade-buffered_99-47>
#       * <Item id=hillshade-buffered_99-49>
#       * <Item id=hillshade-buffered_99-50>
#       * <Item id=hillshade-buffered_99-51>
#       * <Item id=hillshade-buffered_99-52>
#       * <Item id=hillshade-buffered_99-53>
#       * <Item id=hillshade-buffered_99-54>
#       * <Item id=hillshade-buffered_99-57>
#       * <Item id=hillshade-buffered_99-58>
#       * <Item id=hillshade-buffered_99-59>
#       * <Item id=hillshade-buffered_99-60>
#       * <Item id=hillshade-buffered_99-61>
#       * <Item id=hillshade-buffered_99-62>
#       * <Item id=hillshade-buffered_99-63>
#       * <Item id=hillshade-buffered_99-64>
#       * <Item id=hillshade-buffered_99-65>
# None
# {
#   "id": "shade-out-catalog",
#   "stac_version": "1.0.0-beta.2",
#   "description": "Hillshade Buffered GeoTrellis Catalog.",
#   "links": [
#     {
#       "rel": "root",
#       "href": "s3://geotrellis-workshop/shade-out-catalog-absolute/catalog.json",
#       "type": "application/json"
#     },
#     {
#       "rel": "child",
#       "href": "s3://geotrellis-workshop/shade-out-catalog-absolute/hillshade-buffered/collection.json",
#       "type": "application/json"
#     },
#     {
#       "rel": "self",
#       "href": "s3://geotrellis-workshop/shade-out-catalog-absolute/catalog.json",
#       "type": "application/json"
#     }
#   ]
# }
